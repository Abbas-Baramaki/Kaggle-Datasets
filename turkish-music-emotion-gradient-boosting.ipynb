# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# ## https://www.kaggle.com/datasets/joebeachcapital/turkish-music-emotion
#
#
# it work and i think can be better but is enough for my training

# %%
data = pd.read_csv('/kaggle/input/turkish-music-emotion/Acoustic Features.csv')

# %%
data
# Out:
#      Class  _RMSenergy_Mean  _Lowenergy_Mean  _Fluctuation_Mean  _Tempo_Mean  \
# 0        0            0.052            0.591              9.136      130.043
# 1        0            0.125            0.439              6.680      142.240
# 2        0            0.046            0.639             10.578      188.154
# 3        0            0.135            0.603             10.442       65.991
# 4        0            0.066            0.591              9.769       88.890
# ..     ...              ...              ...                ...          ...
# 395      3            0.174            0.578              5.265      161.144
# 396      3            0.176            0.498              5.042      179.787
# 397      3            0.187            0.557              4.724      134.032
# 398      3            0.140            0.573              4.470      113.600
# 399      3            0.086            0.475              5.343      151.748
#
# ...

# %%
data.isnull().sum()
# Out:
# Class                                             0
# _RMSenergy_Mean                                   0
# _Lowenergy_Mean                                   0
# _Fluctuation_Mean                                 0
# _Tempo_Mean                                       0
# _MFCC_Mean_1                                      0
# _MFCC_Mean_2                                      0
# _MFCC_Mean_3                                      0
# _MFCC_Mean_4                                      0
# _MFCC_Mean_5                                      0
# _MFCC_Mean_6                                      0
# _MFCC_Mean_7                                      0
# _MFCC_Mean_8                                      0
# _MFCC_Mean_9                                      0
# _MFCC_Mean_10                                     0
# _MFCC_Mean_11                                     0
# _MFCC_Mean_12                                     0
# _MFCC_Mean_13                                     0
# ...

# %%
classes = list(data['Class'].unique())
data['Class'] = data['Class'].apply(lambda x: classes.index(x))

# %%
y = data['Class']
x = data.drop('Class',axis=1)

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
x_train , x_test, y_train , y_test = train_test_split(x,y,train_size=0.7,random_state=13)

# %%
gb = GradientBoostingClassifier(n_estimators=200)
gb.fit(x_train,y_train)
gb.score(x_test,y_test)
