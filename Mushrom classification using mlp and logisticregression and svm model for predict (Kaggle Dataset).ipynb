# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split 

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

# %%
data = pd.read_csv('/kaggle/input/mushroom-classification/mushrooms.csv')

# %%
data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
encoder = LabelEncoder()
classe = []


for column in range(len(data.columns)):
    data[data.columns[column]] = encoder.fit_transform(data[data.columns[column]])
    cla = {index:label for index,label in enumerate(encoder.classes_)}
    classe.append(cla)

# %%
x = data.drop('class',axis=1)
y = data['class']

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int64

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,train_size=0.80)

# %%
y_train
# Out:
# 5092    1
# 7174    1
# 1249    0
# 1688    0
# 6956    1
#        ..
# 4185    1
# 6070    1
# 7418    0
# 5565    1
# 7086    0
# Name: class, Length: 6499, dtype: int64

# %%
log_model = LogisticRegression(verbose=True)
svm = SVC(C = 1.0 , kernel='rbf')
mlp = MLPClassifier()

# %%
log_model.fit(x_train , y_train)
svm.fit(x_train , y_train)
mlp.fit(x_train , y_train)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           23     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.50476D+03    |proj g|=  6.71800D+03
#
# At iterate   50    f=  1.17595D+03    |proj g|=  5.30876D+01
#
# At iterate  100    f=  1.14933D+03    |proj g|=  2.26805D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    23    100    117      1     0     0   2.268D+01   1.149D+03
#   F =   1149.3272286501372
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#  This problem is unconstrained.
# ...

# %%
print(f'log score {log_model.score(x_test,y_test)}\n svm score {svm.score(x_train,y_train)},\nmlp score {mlp.score(x_test,y_test)} ')
# Out:
# log score 0.9563076923076923
#  svm score 0.9907678104323742,
# mlp score 1.0

# %%
Y
# Out:
#       class
# 0         1
# 1         0
# 2         0
# 3         1
# 4         0
# ...     ...
# 8119      0
# 8120      0
# 8121      0
# 8122      1
# 8123      0
#
# [8124 rows x 1 columns]
