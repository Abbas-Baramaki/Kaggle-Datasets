# %%
import numpy as np
import pandas as pd
import seaborn as sns


from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
data = pd.read_csv('/kaggle/input/red-wine-quality-cortez-et-al-2009/winequality-red.csv')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  sulphates  \
# 0               7.4             0.700         0.00             1.9       0.56
# 1               7.8             0.880         0.00             2.6       0.68
# 2               7.8             0.760         0.04             2.3       0.65
# 3              11.2             0.280         0.56             1.9       0.58
# 4               7.4             0.700         0.00             1.9       0.56
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0       0.58
# 1595            5.9             0.550         0.10             2.2       0.76
# 1596            6.3             0.510         0.13             2.3       0.75
# 1597            5.9             0.645         0.12             2.0       0.71
# 1598            6.0             0.310         0.47             3.6       0.66
#
#       alcohol  quality
# ...

# %%
sns.heatmap(data.corr(),annot=True,vmax=1,vmin=-0.1)
# Out:
# <Axes: >

# %%
fetures_corr = ['alcohol','sulphates','citric acid','fixed acidity']

# %%
X = data[fetures_corr]
Y = data['quality']

# %%
x_train , x_test , y_train , y_test = train_test_split(X,Y,train_size=0.85)

# %%
svm = SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
nn = MLPClassifier(hidden_layer_sizes=(256,256),max_iter = 500 , activation='relu',verbose = 0)
nn.fit(x_train , y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(256, 256), max_iter=500, verbose=0)

# %%
forest = RandomForestClassifier(n_estimators=200)
forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
print(f'''
SVM SCORE : {svm.score(x_test,y_test)}
MLP SCORE : {nn.score(x_test,y_test)}
FOR SCORE : {forest.score(x_test,y_test)}

''')
# Out:
# SVM SCORE : 0.5333333333333333
# MLP SCORE : 0.5791666666666667
# FOR SCORE : 0.6791666666666667
